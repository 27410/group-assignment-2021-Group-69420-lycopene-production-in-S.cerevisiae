# %%
from cobra.io import read_sbml_model
# !carve --refseq GCF_008124905.1 --output Strepto.xml --gapfill LB --init LB
# Out:
# File exists, skipping.
# diamond v2.0.4.142 (C) Max Planck Society for the Advancement of Science
# Documentation, support and updates available at http://www.diamondsearch.org
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Temporary directory:
# Opening the database...  [0.073s]
# Percentage range of top alignment score to report hits: 10
# Reference = /usr/local/lib/python3.6/dist-packages/carveme/data/input/bigg_proteins.dmnd
# Sequences = 84674
# Letters = 32226457
# Block size = 2000000000
# Opening the input file...  [0.036s]
# Opening the output file...  [0.001s]
# Loading query sequences...  [0.026s]
# Masking queries...  [0.15s]
# Building query seed set...  [0s]
# Algorithm: Double-indexed
# Building query histograms...  [0.211s]
# Allocating buffers...  [0s]
# Loading reference sequences...  [0.074s]
# Masking reference...  [0.562s]
# Initializing temporary storage...  [0.001s]
# Building reference histograms...  [1.719s]
# ...

# %%
model = read_sbml_model('Strepto.xml')
print("Number of reactions:", len(model.reactions))
print("Number of metabolites:", len(model.metabolites))
print("Number of genes included in the model:", len(model.genes))
print("% of genes in model compared to the number of coding genes in Vibrio natrigens(4451 genes):",(len(model.genes)/4451)*100)
# Out:
# Number of reactions: 2236
# Number of metabolites: 1434
# Number of genes included in the model: 1360
# % of genes in model compared to the number of coding genes in Vibrio natrigens(4451 genes): 30.554931476072795

# %%
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds Strepto.xml --filename Strepto.html
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0
# rootdir: /usr/local/lib/python3.6/dist-packages/memote/suite/tests
# collected 146 items / 1 skipped / 145 selected
#
# ../../../../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..         [ 44%]
# ../../../../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F.F...FF                                                   [ 60%]
# ../../../../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_biomass.py . [ 60%]
# F.....F.F                                                                [ 67%]
# ../../../../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_consistency.py s [ 67%]
# F
